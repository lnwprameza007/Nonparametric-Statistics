# %%
import pandas as pd

# %%
df  = pd.read_csv('C:/Users/Noppon/Desktop/Prame/Non-para/Final/epldata_final.csv')

# %%
country = df['nationality'].value_counts()
country
# Out:
# nationality
# England                156
# Spain                   28
# France                  25
# Netherlands             20
# Belgium                 18
#                       ...
# Benin                    1
# Bermuda                  1
# Trinidad and Tobago      1
# Slovenia                 1
# New Zealand              1
# Name: count, Length: 61, dtype: int64

# %%
region = df['region'].value_counts().sort_index()
region
# Out:
# region
# 1.0    156
# 2.0    207
# 3.0     41
# 4.0     56
# Name: count, dtype: int64

# %%
region_info = pd.DataFrame({
    'region_id': [1.0, 2.0, 3.0, 4.0],
    'region_name': ['England', 'Europe', 'America', 'Other']
})
region_info
# Out:
#    region_id region_name
# 0        1.0     England
# 1        2.0      Europe
# 2        3.0     America
# 3        4.0       Other

# %%
df2 = pd.merge(df, region_info, left_on='region', right_on='region_id')
df2
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 2              Petr Cech   Arsenal   35       GK             4           7.0
# 3           Theo Walcott   Arsenal   28       RW             1          20.0
# 4      Laurent Koscielny   Arsenal   31       CB             3          22.0
# ..                   ...       ...  ...      ...           ...           ...
# 455  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 456       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 457            Sam Byram  West+Ham   23       RB             3           4.5
# 458      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 459         Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %%
df2['fpl_sel'] = df2['fpl_sel'].str.rstrip('%').astype(float)
df2['fpl_sel'] = df2['fpl_sel'].astype(int)
df2
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 2              Petr Cech   Arsenal   35       GK             4           7.0
# 3           Theo Walcott   Arsenal   28       RW             1          20.0
# 4      Laurent Koscielny   Arsenal   31       CB             3          22.0
# ..                   ...       ...  ...      ...           ...           ...
# 455  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 456       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 457            Sam Byram  West+Ham   23       RB             3           4.5
# 458      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 459         Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %%
df2.drop(columns=['region_id'], inplace=True)

# %%
df2
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 2              Petr Cech   Arsenal   35       GK             4           7.0
# 3           Theo Walcott   Arsenal   28       RW             1          20.0
# 4      Laurent Koscielny   Arsenal   31       CB             3          22.0
# ..                   ...       ...  ...      ...           ...           ...
# 455  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 456       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 457            Sam Byram  West+Ham   23       RB             3           4.5
# 458      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 459         Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %%
df2.to_csv('epl_clean.csv', index=False)
